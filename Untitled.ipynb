# %% [markdown]
# ## Creating TractorTEK mysql database

# %%
pip install mysql-connector-python

# %%
import mysql.connector as mysql
import pandas as pd
from mysql.connector import Error

# %%
## creating connection to mysql and creating tractortek database ##

conn = mysql.connect(host='localhost', user='root', password='pw123')

if conn.is_connected():
    cursor = conn.cursor()
    cursor.execute("CREATE DATABASE tractortek")
    print("Database created successfully")
else:
    print("Error")
# Out:
# Database created successfully

# %% [markdown]
# ## Creating tables in MySQL

# %%
prodMain = pd.read_csv(r"C:\Users\mdbro\OneDrive\Documents\teksystems_da\capstone1\prod_info.csv")
prodMain.head()
# Out:
#     prod_id                   prod_name prod_manufc   esp_id
# 0  PROD_006      ZT2000 Zero Turn Mower      Bobcat  ESP_006
# 1  PROD_005                   UV34 Gas       Bobcat  ESP_005
# 2  PROD_004  CT1021 Sub-Compact Tractor      Bobcat  ESP_004
# 3  PROD_007       S70 Skid Steer Loader      Bobcat  ESP_007
# 4  PROD_002                       CUV82         Cat  ESP_002

# %%
conn = mysql.connect(host='localhost', 
                     database='tractortek', 
                     user='root', 
                     password='pw123')
if conn.is_connected():
    cursor = conn.cursor()
    cursor.execute("select database();")
    record = cursor.fetchone()
    print("You're connected to the database: ", record)
    cursor.execute('DROP TABLE IF EXISTS prod_info;')
    print('Creating table')
    cursor.execute("CREATE TABLE prod_info(prod_id VARCHAR(8), prod_name VARCHAR(30), prod_manufc VARCHAR(30), esp_id VARCHAR(8))")
    print("Table is ready...")
    
    for i, row in prodMain.iterrows():
        sql = "INSERT INTO tractortek.prod_info VALUES (%s,%s,%s,%s)"
        cursor.execute(sql, tuple(row))
        print("Records inserted")
        conn.commit()
else:
    print("Error connecting to Mysql")
# Out:
# You're connected to the database:  ('tractortek',)
# Creating table
# Table is ready...
# Records inserted
# Records inserted
# Records inserted
# Records inserted
# Records inserted
# Records inserted
# Records inserted
# Records inserted

# %%
prodPrices = pd.read_csv(r"C:\Users\mdbro\OneDrive\Documents\teksystems_da\capstone1\prod_prices.csv")
prodPrices.head()
# Out:
#    id   prod_id quarter  year  price
# 0   1  PROD_006      Q1  2020   4575
# 1   2  PROD_006      Q2  2020   4575
# 2   3  PROD_006      Q3  2020   4575
# 3   4  PROD_006      Q4  2020   4669
# 4   5  PROD_006      Q1  2021   4949

# %%
prodSales = pd.read_csv(r"C:\Users\mdbro\OneDrive\Documents\teksystems_da\capstone1\prod_sales.csv")
prodSales.head()
# Out:
#    sales_id   prod_id  emp_id  year week  quantity
# 0         1  PROD_001  EMP244  2021   W0        23
# 1         2  PROD_001  EMP244  2021   W1        27
# 2         3  PROD_001  EMP244  2021   W2        37
# 3         4  PROD_001  EMP244  2021   W3        47
# 4         5  PROD_001  EMP244  2021   W4        42

# %%
warrSales = pd.read_csv(r"C:\Users\mdbro\OneDrive\Documents\teksystems_da\capstone1\warranty_sales.csv")
warrSales.head()
# Out:
#    sales_id   esp_id  emp_id  year week  quantity
# 0         1  ESP_001  EMP234  2020   W0         3
# 1         2  ESP_001  EMP234  2020   W1         3
# 2         3  ESP_001  EMP234  2020   W2         3
# 3         4  ESP_001  EMP234  2020   W3         6
# 4         5  ESP_001  EMP234  2020   W4        12

# %%
warrPrices = pd.read_csv(r"C:\Users\mdbro\OneDrive\Documents\teksystems_da\capstone1\warranty_prices.csv")
warrPrices.head()
# Out:
#    id   esp_id  price_2020  price_2021
# 0   1  ESP_006         372         450
# 1   2  ESP_005         843         989
# 2   3  ESP_004         843         989
# 3   4  ESP_007        1027        1100
# 4   5  ESP_002         843         989

# %%
emplTbl = pd.read_csv(r"C:\Users\mdbro\OneDrive\Documents\teksystems_da\capstone1\employees.csv")
emplTbl.head()
# Out:
#    emp_id              name paygrade region
# 0  EMP244       Evans, Gina      C12     NW
# 1  EMP256     Lawson, Harry      C11     NW
# 2  EMP234    Bachmann, Jane      C13     NW
# 3  EMP267  Clement, Beverly      C14     SW
# 4  EMP290      Allen, Maude      C12     SW

# %%
conn = mysql.connect(host='localhost', 
                     database='tractortek', 
                     user='root', 
                     password='pw123')
if conn.is_connected():
    cursor = conn.cursor()
    cursor.execute("select database();")
    record = cursor.fetchone()
    print("You're connected to the database: ", record)
    cursor.execute('DROP TABLE IF EXISTS prod_sales;')
    print('Creating table')
    cursor.execute("CREATE TABLE prod_sales(sales_id INT PRIMARY KEY, prod_id VARCHAR(8), emp_id VARCHAR(8), year YEAR, week VARCHAR(5), quantity INT)")
    print("Table is ready...")
    
    for i, row in prodSales.iterrows():
        sql = "INSERT INTO tractortek.prod_sales VALUES (%s,%s,%s,%s,%s,%s)"
        cursor.execute(sql, tuple(row))
        print("Records inserted")
        conn.commit()
else:
    print("Error connecting to Mysql")
# Out:
# You're connected to the database:  ('tractortek',)
# Creating table
# Table is ready...
# Records inserted
# Records inserted
# Records inserted
# Records inserted
# Records inserted
# Records inserted
# Records inserted
# Records inserted
# Records inserted
# Records inserted
# Records inserted
# Records inserted
# Records inserted
# Records inserted
# Records inserted
# Records inserted
# Records inserted
# Records inserted
# Records inserted
# Records inserted
# Records inserted
# Records inserted
# Records inserted
# Records inserted
# Records inserted
# Records inserted
# Records inserted
# Records inserted
# Records inserted
# Records inserted
# Records inserted
# Records inserted
# Records inserted
# Records inserted
# Records inserted
# Records inserted
# Records inserted
# Records inserted
# Records inserted
# Records inserted
# Records inserted
# Records inserted
# Records inserted
# Records inserted
# Records inserted
# Records inserted
# Records inserted
# ...

# %%
conn = mysql.connect(host='localhost', 
                     database='tractortek', 
                     user='root', 
                     password='pw123')
if conn.is_connected():
    cursor = conn.cursor()
    cursor.execute("select database();")
    record = cursor.fetchone()
    print("You're connected to the database: ", record)
    cursor.execute('DROP TABLE IF EXISTS prod_prices;')
    print('Creating table')
    cursor.execute("CREATE TABLE prod_prices(id INT PRIMARY KEY, prod_id VARCHAR(8), quarter VARCHAR(3), year YEAR, price BIGINT)")
    print("Table is ready...")
    
    for i, row in prodPrices.iterrows():
        sql = "INSERT INTO tractortek.prod_prices VALUES (%s,%s,%s,%s,%s)"
        cursor.execute(sql, tuple(row))
        print("Records inserted")
        conn.commit()
else:
    print("Error connecting to Mysql")
# Out:
# You're connected to the database:  ('tractortek',)
# Creating table
# Table is ready...
# Records inserted
# Records inserted
# Records inserted
# Records inserted
# Records inserted
# Records inserted
# Records inserted
# Records inserted
# Records inserted
# Records inserted
# Records inserted
# Records inserted
# Records inserted
# Records inserted
# Records inserted
# Records inserted
# Records inserted
# Records inserted
# Records inserted
# Records inserted
# Records inserted
# Records inserted
# Records inserted
# Records inserted
# Records inserted
# Records inserted
# Records inserted
# Records inserted
# Records inserted
# Records inserted
# Records inserted
# Records inserted
# Records inserted
# Records inserted
# Records inserted
# Records inserted
# Records inserted
# Records inserted
# Records inserted
# Records inserted
# Records inserted
# Records inserted
# Records inserted
# Records inserted
# Records inserted
# Records inserted
# Records inserted
# ...

# %%
conn = mysql.connect(host='localhost', 
                     database='tractortek', 
                     user='root', 
                     password='pw123')
if conn.is_connected():
    cursor = conn.cursor()
    cursor.execute("select database();")
    record = cursor.fetchone()
    print("You're connected to the database: ", record)
    cursor.execute('DROP TABLE IF EXISTS warranty_sales;')
    print('Creating table')
    cursor.execute("CREATE TABLE warranty_sales(sales_id INT PRIMARY KEY, esp_id VARCHAR(8) NOT NULL, emp_id VARCHAR(10) NOT NULL, year YEAR, week VARCHAR(5), quantity INT)")
    print("Table is ready...")
    
    for i, row in warrSales.iterrows():
        sql = "INSERT INTO tractortek.warranty_sales VALUES (%s,%s,%s,%s,%s,%s)"
        cursor.execute(sql, tuple(row))
        print("Records inserted")
        conn.commit()
else:
    print("Error connecting to Mysql")
# Out:
# You're connected to the database:  ('tractortek',)
# Creating table
# Table is ready...
# Records inserted
# Records inserted
# Records inserted
# Records inserted
# Records inserted
# Records inserted
# Records inserted
# Records inserted
# Records inserted
# Records inserted
# Records inserted
# Records inserted
# Records inserted
# Records inserted
# Records inserted
# Records inserted
# Records inserted
# Records inserted
# Records inserted
# Records inserted
# Records inserted
# Records inserted
# Records inserted
# Records inserted
# Records inserted
# Records inserted
# Records inserted
# Records inserted
# Records inserted
# Records inserted
# Records inserted
# Records inserted
# Records inserted
# Records inserted
# Records inserted
# Records inserted
# Records inserted
# Records inserted
# Records inserted
# Records inserted
# Records inserted
# Records inserted
# Records inserted
# Records inserted
# Records inserted
# Records inserted
# Records inserted
# ...

# %%
conn = mysql.connect(host='localhost', 
                     database='tractortek', 
                     user='root', 
                     password='pw123')
if conn.is_connected():
    cursor = conn.cursor()
    cursor.execute("select database();")
    record = cursor.fetchone()
    print("You're connected to the database: ", record)
    cursor.execute('DROP TABLE IF EXISTS warranty_prices;')
    print('Creating table')
    cursor.execute("CREATE TABLE warranty_prices(id INT PRIMARY KEY, esp_id VARCHAR(8) NOT NULL, price_2020 BIGINT, price_2021 BIGINT)")
    print("Table is ready...")
    
    for i, row in warrPrices.iterrows():
        sql = "INSERT INTO tractortek.warranty_prices VALUES (%s,%s,%s,%s)"
        cursor.execute(sql, tuple(row))
        print("Records inserted")
        conn.commit()
else:
    print("Error connecting to Mysql")
# Out:
# You're connected to the database:  ('tractortek',)
# Creating table
# Table is ready...
# Records inserted
# Records inserted
# Records inserted
# Records inserted
# Records inserted
# Records inserted
# Records inserted
# Records inserted

# %%
conn = mysql.connect(host='localhost', 
                     database='tractortek', 
                     user='root', 
                     password='pw123')
if conn.is_connected():
    cursor = conn.cursor()
    cursor.execute("select database();")
    record = cursor.fetchone()
    print("You're connected to the database: ", record)
    cursor.execute('DROP TABLE IF EXISTS employees;')
    print('Creating table')
    cursor.execute("CREATE TABLE employees(emp_id VARCHAR(10), name VARCHAR(30), paygrade VARCHAR(5), region VARCHAR(2))")
    print("Table is ready...")
    
    for i, row in emplTbl.iterrows():
        sql = "INSERT INTO tractortek.employees VALUES (%s,%s,%s,%s)"
        cursor.execute(sql, tuple(row))
        print("Records inserted")
        conn.commit()
else:
    print("Error connecting to Mysql")
# Out:
# You're connected to the database:  ('tractortek',)
# Creating table
# Table is ready...
# Records inserted
# Records inserted
# Records inserted
# Records inserted
# Records inserted
